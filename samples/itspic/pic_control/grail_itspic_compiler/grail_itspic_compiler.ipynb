# %%
import exceptions

# this set will contain all nodes
### set as unique values will be inserted;
### list is used because I want an index
# each node is a unique INTEGER
nodes = []

# this set will contain all actions
# each action is a unique String
actions = []

# this set will contain all transitions
# each transition is a tuple of (origin node, action, destiny node)
transitions = []

#TODO hardcoded File name
f = open('IDES/Supcon.fm', 'r')

for line in f:
    s = line.replace('\n', '').split(' ')
    if len(s) != 3:
        raise Exception('Input line dont have 3 words')
    try:
        origin_node = int(s[0])
        try:
            nodes.index(origin_node)
        except ValueError:
            nodes.append(origin_node)
            pass
    except exceptions.ValueError:
        if s[0] == '(START)':
            origin_node = -1
        else:
            raise Exception('Cant understand origin node, found: %s' % s[0])
        
    try:
        dst_node = int(s[2])
        try:
            nodes.index(dst_node)
        except ValueError:
            nodes.append(dst_node)
            pass
    except exceptions.ValueError:
        if s[2] == '(FINAL)':
            dst_node = -2
        else:
            raise Exception('Cant understand dst node, found: %s' % s[2])
    
    action = s[1]
    if action == '-|' or action == '|-':
        continue
    try:
        actions.index(action)
    except ValueError:
        actions.append(action)
        pass
    
    transitions.append( (origin_node,action,dst_node) )

f.close()

print 'Number of nodes: ', len(nodes)
print 'Number of actions:', len(actions)
print 'Number of transitions:', len(transitions)
# Out:
# Number of nodes:  494
# Number of actions: 24
# Number of transitions: 1108

# %%
for ai in range(len(actions)):
        print '#define EVENT_%s %d' % (actions[ai].upper(),ai)
        ac += 1

print
print

for a in actions:
    if not a.startswith('end_'):
        print 'void %s(void) {\n}\n' % a
        print 'void update_%s(void) {\n}\n' % a
# Out:
# #define EVENT_MOVE_0 0
# #define EVENT_INPUT_BOX 1
# #define EVENT_END_MOVE_0 2
# #define EVENT_END_INPUT_BOX 3
# #define EVENT_INPUT_PALLET 4
# #define EVENT_FREE_BOX 5
# #define EVENT_END_INPUT_PALLET 6
# #define EVENT_END_FREE_BOX 7
# #define EVENT_MOVE_3 8
# #define EVENT_CLOSE_FLOOR 9
# #define EVENT_END_MOVE_3 10
# #define EVENT_END_CLOSE_FLOOR 11
# #define EVENT_BLOCK_BOX 12
# #define EVENT_FIT_BOX 13
# #define EVENT_END_FIT_BOX 14
# #define EVENT_END_BLOCK_BOX 15
# #define EVENT_OPEN_FLOOR 16
# #define EVENT_END_OPEN_FLOOR 17
# #define EVENT_RELEASE_BOX 18
# #define EVENT_END_RELEASE_BOX 19
# #define EVENT_MOVE_2 20
# #define EVENT_END_MOVE_2 21
# #define EVENT_MOVE_1 22
# #define EVENT_END_MOVE_1 23
#
#
# void move_0(void) {
# }
#
# void update_move_0(void) {
# }
#
# void input_box(void) {
# }
#
# void update_input_box(void) {
# }
#
# void input_pallet(void) {
# }
#
# void update_input_pallet(void) {
# }
#
# void free_box(void) {
# }
#
# void update_free_box(void) {
# }
#
# void move_3(void) {
# }
#
# void update_move_3(void) {
# }
#
# void close_floor(void) {
# }
#
# void update_close_floor(void) {
# }
#
# void block_box(void) {
# }
#
# void update_block_box(void) {
# }
#
# void fit_box(void) {
# }
#
# void update_fit_box(void) {
# }
#
# void open_floor(void) {
# }
#
# void update_open_floor(void) {
# }
#
# void release_box(void) {
# }
#
# void update_release_box(void) {
# }
#
# void move_2(void) {
# }
#
# void update_move_2(void) {
# }
#
# void move_1(void) {
# }
#
# void update_move_1(void) {
# }

# %%
dir("")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_formatter_field_name_split',
#  '_formatter_parser',
#  'capitalize',
#  'center',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdigit',
#  'islower',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
["(%d,%d)" % (nodes[i],i) for i in range(len(nodes))]
# Out:
# ['(0,0)',
#  '(4,1)',
#  '(8,2)',
#  '(26,3)',
#  '(27,4)',
#  '(39,5)',
#  '(88,6)',
#  '(89,7)',
#  '(91,8)',
#  '(106,9)',
#  '(197,10)',
#  '(198,11)',
#  '(200,12)',
#  '(217,13)',
#  '(354,14)',
#  '(356,15)',
#  '(358,16)',
#  '(343,17)',
#  '(377,18)',
#  '(548,19)',
#  '(546,20)',
#  '(564,21)',
#  '(568,22)',
#  '(572,23)',
#  '(591,24)',
#  '(802,25)',
#  '(800,26)',
#  '(826,27)',
#  '(831,28)',
#  '(837,29)',
#  '(856,30)',
#  '(794,31)',
#  '(1104,32)',
#  '(1108,33)',
#  '(1085,34)',
#  '(1116,35)',
#  '(1149,36)',
#  '(1150,37)',
#  '(1154,38)',
#  '(1158,39)',
#  '(1187,40)',
#  '(1447,41)',
#  '(1451,42)',
#  '(1439,43)',
#  '(1480,44)',
#  '(1481,45)',
#  '(1489,46)',
#  '(1499,47)',
#  '(1538,48)',
#  '(1539,49)',
#  '(1535,50)',
#  '(1547,51)',
#  '(1577,52)',
#  '(1846,53)',
#  '(1851,54)',
#  '(1850,55)',
#  '(1859,56)',
#  '(1860,57)',
#  '(1868,58)',
#  '(1917,59)',
#  '(1909,60)',
#  '(1920,61)',
#  '(1928,62)',
#  '(1944,63)',
#  '(1982,64)',
#  '(1981,65)',
#  '(1934,66)',
#  '(1988,67)',
#  '(1992,68)',
#  '(2031,69)',
#  '(2302,70)',
#  '(2303,71)',
#  '(2301,72)',
#  '(2311,73)',
#  '(2310,74)',
#  '(2314,75)',
#  '(2325,76)',
#  '(2317,77)',
#  '(2328,78)',
#  '(2336,79)',
#  '(2405,80)',
#  '(2406,81)',
#  '(2420,82)',
#  '(2423,83)',
#  '(2440,84)',
#  '(2442,85)',
#  '(2492,86)',
#  '(2491,87)',
#  '(2488,88)',
#  '(2506,89)',
#  '(2820,90)',
#  '(2821,91)',
#  '(2819,92)',
#  '(2825,93)',
#  '(2815,94)',
#  '(2828,95)',
#  '(2836,96)',
#  '(2756,97)',
#  '(2839,98)',
#  '(2841,99)',
#  '(2847,100)',
#  '(2848,101)',
#  '(2862,102)',
#  '(2865,103)',
#  '(2978,104)',
#  '(2979,105)',
#  '(2999,106)',
#  '(3025,107)',
#  '(3011,108)',
#  '(3076,109)',
#  '(3072,110)',
#  '(3079,111)',
#  '(3309,112)',
#  '(3332,113)',
#  '(3330,114)',
#  '(3413,115)',
#  '(3414,116)',
#  '(3408,117)',
#  '(3419,118)',
#  '(3420,119)',
#  '(3424,120)',
#  '(3427,121)',
#  '(3432,122)',
#  '(3435,123)',
#  '(3446,124)',
#  '(3448,125)',
#  '(3462,126)',
#  '(3463,127)',
#  '(3483,128)',
#  '(3629,129)',
#  '(3631,130)',
#  '(3665,131)',
#  '(3663,132)',
#  '(3734,133)',
#  '(3730,134)',
#  '(3947,135)',
#  '(3948,136)',
#  '(3945,137)',
#  '(3983,138)',
#  '(3988,139)',
#  '(4089,140)',
#  '(4090,141)',
#  '(4084,142)',
#  '(4099,143)',
#  '(4100,144)',
#  '(4112,145)',
#  '(4115,146)',
#  '(4120,147)',
#  '(4123,148)',
#  '(4129,149)',
#  '(4141,150)',
#  '(4166,151)',
#  '(4168,152)',
#  '(4352,153)',
#  '(4390,154)',
#  '(4371,155)',
#  '(4461,156)',
#  '(4650,157)',
#  '(4651,158)',
#  '(4658,159)',
#  '(4620,160)',
#  '(4661,161)',
#  '(4705,162)',
#  '(4709,163)',
#  '(4836,164)',
#  '(4837,165)',
#  '(4846,166)',
#  '(4847,167)',
#  '(4864,168)',
#  '(4866,169)',
#  '(4882,170)',
#  '(4885,171)',
#  '(4891,172)',
#  '(4939,173)',
#  '(5139,174)',
#  '(5145,175)',
#  '(5355,176)',
#  '(5347,177)',
#  '(5356,178)',
#  '(5408,179)',
#  '(5411,180)',
#  '(5422,181)',
#  '(5425,182)',
#  '(5471,183)',
#  '(5637,184)',
#  '(5638,185)',
#  '(5655,186)',
#  '(5657,187)',
#  '(5678,188)',
#  '(5696,189)',
#  '(5923,190)',
#  '(6097,191)',
#  '(6098,192)',
#  '(6114,193)',
#  '(6115,194)',
#  '(6197,195)',
#  '(6200,196)',
#  '(6214,197)',
#  '(6257,198)',
#  '(6452,199)',
#  '(6454,200)',
#  '(6475,201)',
#  '(6848,202)',
#  '(6849,203)',
#  '(6879,204)',
#  '(6881,205)',
#  '(6980,206)',
#  '(6981,207)',
#  '(7024,208)',
#  '(7230,209)',
#  '(7572,210)',
#  '(7574,211)',
#  '(7613,212)',
#  '(7704,213)',
#  '(7706,214)',
#  '(7728,215)',
#  '(8228,216)',
#  '(8223,217)',
#  '(8340,218)',
#  '(8305,219)',
#  '(8357,220)',
#  '(8775,221)',
#  '(8773,222)',
#  '(8836,223)',
#  '(8839,224)',
#  '(9203,225)',
#  '(9082,226)',
#  '(9250,227)',
#  '(9414,228)',
#  '(9410,229)',
#  '(9522,230)',
#  '(9672,231)',
#  '(9773,232)',
#  '(9895,233)',
#  '(9989,234)',
#  '(10109,235)',
#  '(10100,236)',
#  '(10198,237)',
#  '(10307,238)',
#  '(10308,239)',
#  '(10401,240)',
#  '(10402,241)',
#  '(10518,242)',
#  '(10512,243)',
#  '(10514,244)',
#  '(10613,245)',
#  '(10612,246)',
#  '(10615,247)',
#  '(10735,248)',
#  '(10730,249)',
#  '(10734,250)',
#  '(10741,251)',
#  '(10740,252)',
#  '(10845,253)',
#  '(10846,254)',
#  '(10839,255)',
#  '(10852,256)',
#  '(10975,257)',
#  '(10976,258)',
#  '(10974,259)',
#  '(10981,260)',
#  '(10949,261)',
#  '(10989,262)',
#  '(10992,263)',
#  '(11099,264)',
#  '(11104,265)',
#  '(11112,266)',
#  '(11115,267)',
#  '(11119,268)',
#  '(11215,269)',
#  '(11221,270)',
#  '(11225,271)',
#  '(11250,272)',
#  '(11251,273)',
#  '(11255,274)',
#  '(11258,275)',
#  '(11277,276)',
#  '(11279,277)',
#  '(11400,278)',
#  '(11401,279)',
#  '(11418,280)',
#  '(11421,281)',
#  '(11527,282)',
#  '(11522,283)',
#  '(11528,284)',
#  '(11540,285)',
#  '(11578,286)',
#  '(11581,287)',
#  '(11586,288)',
#  '(11589,289)',
#  '(11608,290)',
#  '(11745,291)',
#  '(11746,292)',
#  '(11765,293)',
#  '(11888,294)',
#  '(11889,295)',
#  '(11898,296)',
#  '(11899,297)',
#  '(11968,298)',
#  '(11971,299)',
#  '(11977,300)',
#  '(11991,301)',
#  '(12141,302)',
#  '(12143,303)',
#  '(12315,304)',
#  '(12316,305)',
#  '(12333,306)',
#  '(12335,307)',
#  '(12409,308)',
#  '(12410,309)',
#  '(12419,310)',
#  '(12578,311)',
#  '(12783,312)',
#  '(12785,313)',
#  '(12806,314)',
#  '(12866,315)',
#  '(12868,316)',
#  '(12874,317)',
#  '(13255,318)',
#  '(13250,319)',
#  '(13320,320)',
#  '(13317,321)',
#  '(13327,322)',
#  '(13679,323)',
#  '(13677,324)',
#  '(13724,325)',
#  '(13727,326)',
#  '(14028,327)',
#  '(14009,328)',
#  '(14063,329)',
#  '(14292,330)',
#  '(14288,331)',
#  '(14309,332)',
#  '(14518,333)',
#  '(14540,334)',
#  '(14726,335)',
#  '(14748,336)',
#  '(14932,337)',
#  '(14923,338)',
#  '(14954,339)',
#  '(15121,340)',
#  '(15122,341)',
#  '(15153,342)',
#  '(15154,343)',
#  '(15333,344)',
#  '(15327,345)',
#  '(15329,346)',
#  '(15365,347)',
#  '(15364,348)',
#  '(15367,349)',
#  '(15557,350)',
#  '(15552,351)',
#  '(15556,352)',
#  '(15563,353)',
#  '(15562,354)',
#  '(15596,355)',
#  '(15597,356)',
#  '(15590,357)',
#  '(15603,358)',
#  '(15806,359)',
#  '(15807,360)',
#  '(15805,361)',
#  '(15812,362)',
#  '(15780,363)',
#  '(15820,364)',
#  '(15823,365)',
#  '(15846,366)',
#  '(15851,367)',
#  '(15859,368)',
#  '(15862,369)',
#  '(15866,370)',
#  '(16060,371)',
#  '(16066,372)',
#  '(16070,373)',
#  '(16095,374)',
#  '(16096,375)',
#  '(16100,376)',
#  '(16103,377)',
#  '(16122,378)',
#  '(16124,379)',
#  '(16143,380)',
#  '(16144,381)',
#  '(16161,382)',
#  '(16164,383)',
#  '(16386,384)',
#  '(16381,385)',
#  '(16387,386)',
#  '(16399,387)',
#  '(16437,388)',
#  '(16440,389)',
#  '(16445,390)',
#  '(16448,391)',
#  '(16467,392)',
#  '(16485,393)',
#  '(16486,394)',
#  '(16505,395)',
#  '(16759,396)',
#  '(16760,397)',
#  '(16769,398)',
#  '(16770,399)',
#  '(16839,400)',
#  '(16842,401)',
#  '(16848,402)',
#  '(16862,403)',
#  '(16881,404)',
#  '(16883,405)',
#  '(17190,406)',
#  '(17191,407)',
#  '(17208,408)',
#  '(17210,409)',
#  '(17284,410)',
#  '(17285,411)',
#  '(17294,412)',
#  '(17318,413)',
#  '(17650,414)',
#  '(17652,415)',
#  '(17673,416)',
#  '(17733,417)',
#  '(17735,418)',
#  '(17741,419)',
#  '(18106,420)',
#  '(18101,421)',
#  '(18171,422)',
#  '(18168,423)',
#  '(18178,424)',
#  '(18513,425)',
#  '(18511,426)',
#  '(18558,427)',
#  '(18561,428)',
#  '(18378,429)',
#  '(18730,430)',
#  '(18739,431)',
#  '(18858,432)',
#  '(18839,433)',
#  '(19039,434)',
#  '(19047,435)',
#  '(19132,436)',
#  '(19152,437)',
#  '(19299,438)',
#  '(19309,439)',
#  '(19396,440)',
#  '(19516,441)',
#  '(19591,442)',
#  '(19746,443)',
#  '(19760,444)',
#  '(19891,445)',
#  '(19902,446)',
#  '(19903,447)',
#  '(20019,448)',
#  '(20020,449)',
#  '(20033,450)',
#  '(20032,451)',
#  '(20035,452)',
#  '(20149,453)',
#  '(20148,454)',
#  '(20151,455)',
#  '(20164,456)',
#  '(20165,457)',
#  '(20158,458)',
#  '(20171,459)',
#  '(20287,460)',
#  '(20288,461)',
#  '(20281,462)',
#  '(20294,463)',
#  '(20298,464)',
#  '(20303,465)',
#  '(20311,466)',
#  '(20314,467)',
#  '(20318,468)',
#  '(20440,469)',
#  '(20445,470)',
#  '(20453,471)',
#  '(20456,472)',
#  '(20460,473)',
#  '(20464,474)',
#  '(20465,475)',
#  '(20482,476)',
#  '(20485,477)',
#  '(20630,478)',
#  '(20631,479)',
#  '(20648,480)',
#  '(20651,481)',
#  '(20658,482)',
#  '(20659,483)',
#  '(20678,484)',
#  '(20841,485)',
#  '(20842,486)',
#  '(20861,487)',
#  '(20873,488)',
#  '(20875,489)',
#  '(21062,490)',
#  '(21064,491)',
#  '(21094,492)',
#  '(21271,493)']
